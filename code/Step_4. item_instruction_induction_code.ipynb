# %%
class myconfig():
    data_path = r"/home/work/lib_data/KISTI/summary.csv"
mcfg = myconfig()

# %%
import pandas as pd
summary_data = pd.read_csv(mcfg.data_path)
title = list(summary_data["title"])
summary = list(summary_data["summary"])

# %%
import ollama
ollama_model = "llama3:70b-instruct"
# ollama.pull(ollama_model)
ollama.list()
# ollama.delete(ollama_model)

# %% [markdown]
# # 본 실험

# %%
response_base = []
response_base_with_rule = []

ii_prompt = []
response_ii_1 = []
response_ii_2 = []
response_ii_3 = []
response_ii_4 = []
response_ii_5 = []

ii_prompt_with_rule = []
response_ii_with_rule_1 = []
response_ii_with_rule_2 = []
response_ii_with_rule_3 = []
response_ii_with_rule_4 = []
response_ii_with_rule_5 = []

# %%
response_ii_with_rule_1 = []
response_ii_with_rule_2 = []
response_ii_with_rule_3 = []
response_ii_with_rule_4 = []
response_ii_with_rule_5 = []

# %% [markdown]
# # Base

# %%
for i in range(len(title)):
    prompt = f"""Classify '0' or '1' without further explanation.
    1: Thing that is traded as a product, a technology, or system that can be commercialized
    0: Thing that is not '1'
  
    Here's a short description of '{title[i]}':
    '{summary[i]}'
  
    According to the description, what is '{title[i]}' categorized as?
    """
    
    
    
    response = ollama.chat(
    model=ollama_model,
    messages=[
        {"role": "system", "content": "You are a classifier."},
        {'role': 'user', 'content': prompt}])
    
    # print(response['message']['content'])
    response_base.append(response['message']['content'])

# %%
for i in range(len(title)):
    prompt = f"""Classify '0' or '1' without further explanation.
    1: Thing that is traded as a product, a technology, or system that can be commercialized
    0: Thing that is not '1' (such as personal names, place names, policies, institutions and organizations, proper nouns, natural phenomena, emotions, history, ideologies, academic discipline industry etc.)
  
    Here's a short description of '{title[i]}':
    '{summary[i]}'
  
    According to the description, what is '{title[i]}' categorized as?
    """
    
    
    
    response = ollama.chat(
    model=ollama_model,
    messages=[
        {"role": "system", "content": "You are a classifier."},
        {'role': 'user', 'content': prompt}])
    
    print(response['message']['content'])
    # response_base_with_rule.append(response['message']['content'])

# %%
response_base_with_rule

# %% [markdown]
# # Instruction induction Prompt

# %%
for i in range(5):
    prompt = """I gave a business expert an instruction, inputs, and summary of the wiki article for each inputs.
    The expert read the instruction and summary, and inference an output for every one of the inputs.

    Here are the input-output pairs:
    Input: *Ion trap and *Summary of Ion trap
    Output: Business Product

    Input: *Laser metal deposition and **Summary of Laser metal
    Output: Business Product

    Input: *Ion trap and **Summary of Ion trap
    Output: Business Product

    Input: *Air separation and **Summary of Air separation
    Output: Business Product

    Input: *Cathode-ray tube and **Summary of Cathode-ray tube
    Output: Business Product

    Input: *Joret line and **Summary of Joret line
    Output: Non-Business Product

    Input: *John Rowsworm and **Summary of John Rowsworm
    Output: Non-Business Product

    Input: *Salishan languages and **Summary of Salishan languages
    Output: Non-Business Product

    Input: *Structral violence and **Summary of Structral violence
    Output: Non-Business Product

    Input: *Night flying restrictions and **Summary of Night flying restrictions
    Output: Non-Business Product

    The instruction was"""

    response = ollama.chat(
        model=ollama_model,
        messages=[
        {"role": "system", "content": "You are a expert of prompt engineering. Generate proper instruction."},
        {'role': 'user', 'content': prompt}],
        )

    # print(response['message']['content'])
    ii_prompt.append(response['message']['content'])

# %%
for i in range(5):
    print(i)
    print(ii_prompt[i])

# %% [markdown]
# # Instruction induction(5개)

# %%
for i in range(len(title)):
    prompt = f"""Classify '0' or '1' without further explanation.
    Read the provided summary of a Wikipedia article and determine whether it can be turned into a business product or not. If the concept described in the summary has potential commercial applications or can be developed into a product or service that can generate revenue, output '1'. Otherwise, output '0'.
      
    input : '{title[i]}'
    summary of input : '{summary[i]}'
    output :
    """
    
    
    
    response = ollama.chat(
    model=ollama_model,
    messages=[
        {"role": "system", "content": "You are a classifier."},
        {'role': 'user', 'content': prompt}])
    
    # print(response['message']['content'])
    response_ii_1.append(response['message']['content'])

# %%
for i in range(len(title)):
    prompt = f"""Classify '0' or '1' without further explanation.
    Read the summary of a Wikipedia article and determine whether it has potential as a business business product or not. If the concept described in the summary has practical applications, can be manufactured or sold, or has a clear use case, classify it as a '1'. Otherwise, classify it as a '0'.
      
    input : '{title[i]}'
    summary of input : '{summary[i]}'
    output :
    """
    
    
    
    response = ollama.chat(
    model=ollama_model,
    messages=[
        {"role": "system", "content": "You are a classifier."},
        {'role': 'user', 'content': prompt}])
    
    # print(response['message']['content'])
    response_ii_2.append(response['message']['content'])

# %%
for i in range(len(title)):
    prompt = f"""Classify '0' or '1' without further explanation.
    Read the summary of a Wikipedia article and determine whether it has the potential to be developed into a business product or not. If the concept described in the summary has practical applications, can be manufactured, or provides a solution to a problem, then output "1". Otherwise, output "0".      
    
    input : '{title[i]}'
    summary of input : '{summary[i]}'
    output :
    """
    
    
    
    response = ollama.chat(
    model=ollama_model,
    messages=[
        {"role": "system", "content": "You are a classifier."},
        {'role': 'user', 'content': prompt}])
    
    # print(response['message']['content'])
    response_ii_3.append(response['message']['content'])

# %%
for i in range(len(title)):
    prompt = f"""Classify '0' or '1' without further explanation.
    Read the summary of each topic and determine whether it has potential business applications or not. If it does, output a '1'. Otherwise, output a '0'.
    
    input : '{title[i]}'
    summary of input : '{summary[i]}'
    output :
    """
    
    
    
    response = ollama.chat(
    model=ollama_model,
    messages=[
        {"role": "system", "content": "You are a classifier."},
        {'role': 'user', 'content': prompt}])
    
    # print(response['message']['content'])
    response_ii_4.append(response['message']['content'])

# %%
for i in range(len(title)):
    prompt = f"""Classify '0' or '1' without further explanation.
Read the provided summary of a technological concept or innovation, and determine whether it has potential business product applications.

For each input, read the corresponding summary and decide if the concept described has potential to be developed into a business product. If you think it has business potential, output "1". Otherwise, output "0".
    
    input : '{title[i]}'
    summary of input : '{summary[i]}'
    output :
    """
    
    
    
    response = ollama.chat(
    model=ollama_model,
    messages=[
        {"role": "system", "content": "You are a classifier."},
        {'role': 'user', 'content': prompt}])
    
    # print(response['message']['content'])
    response_ii_5.append(response['message']['content'])

# %%
response_ii_1

# %%
response_ii_2

# %%
response_ii_3

# %%
response_ii_4

# %%
response_ii_5

# %% [markdown]
# # Instruction induction Prompt_rule

# %%
for i in range(5):
    prompt = """I gave a business expert an instruction, inputs, and summary of the wiki article for each inputs.
    The expert read the instruction and summary, and inference an output for every one of the inputs.
    
    The output criteria are as follows:
    The term Business product refers to any good or technology or system offered for sale to customers. A good is a physical product that a customer can pick up, use, eat or drink. A service is something that a customer experiences, such as a train ride or a phone contract.
    A product can be classified as tangible or intangible. A tangible product is an actual physical object that can be perceived by touch such as a building, vehicle, gadget, or clothing. An intangible product is a product that can only be perceived indirectly such as an insurance policy. These services can be broadly classified under intangible products, which can be durable or nondurable.

    The expert inference the product as a “Business Product” if it was a business product and a “Non-Business Product” otherwise.

    Here are the input-output pairs:
    Input: *Ion trap
    Summary : **Summary of Ion trap
    Output: Business Product

    Input: *Laser metal deposition
    Summary : **Summary of Laser metal
    Output: Business Product

    Input: *Ion trap
    Summary : **Summary of Ion trap
    Output: Business Product

    Input: *Air separation
    Summary : **Summary of Air separation
    Output: Business Product

    Input: *Cathode-ray tube
    Summary : **Summary of Cathode-ray tube
    Output: Business Product

    Input: *Joret line
    Summary : **Summary of Joret line
    Output: Non-Business Product

    Input: *John Rowsworm
    Summary : **Summary of John Rowsworm
    Output: Non-Business Product

    Input: *Salishan languages
    Summary : **Summary of Salishan languages
    Output: Non-Business Product

    Input: *Structral violence
    Summary : **Summary of Structral violence
    Output: Non-Business Product

    Input: *Night flying restrictions
    Summary : **Summary of Night flying restrictions
    Output: Non-Business Product

    The instruction was"""

    response = ollama.chat(
        model=ollama_model,
        messages=[
        {"role": "system", "content": "You are a expert of prompt engineering. Generate proper instruction."},
        {'role': 'user', 'content': prompt}],
        )

    # print(response['message']['content'])
    ii_prompt_with_rule.append(response['message']['content'])

# %%
for i in range(5):
    print(f"[{i}]")
    print(ii_prompt_with_rule[i])

# %% [markdown]
# # Instruction induction Prompt_rule(5개)

# %%
for i in range(len(title)):
    prompt = f"""Classify '0' or '1' without further explanation.
Read the summary of each input and classify it as either a "Business Product" or a "Non-Business Product".

A product can be classified as tangible or intangible. A tangible product is an actual physical object that can be perceived by touch, such as a building, vehicle, gadget, or clothing. An intangible product is a product that can only be perceived indirectly, such as an insurance policy.

Classify the input as a "1" if it refers to a good or service offered for sale to customers, and as a "0" otherwise.

    
    input : '{title[i]}'
    summary of input : '{summary[i]}'
    output :
    """
    
    
    
    response = ollama.chat(
    model=ollama_model,
    messages=[
        {"role": "system", "content": "You are a classifier."},
        {'role': 'user', 'content': prompt}])
    
    # print(response['message']['content'])
    # response_ii_with_rule_1.append(response['message']['content'])

# %%
for i in range(len(title)):
    prompt = f"""Classify '0' or '1' without further explanation.

Read the summary of each input and determine whether it refers to a business product or not. 

* A "1" refers to any good or service offered for sale to customers, which can be either tangible (physical object) or intangible (non-physical).
* Classify an input as a "0" if it does not meet the above criteria.

For each input, read its summary and classify it as either "1" or "0" based on the above criteria.
    
    input : '{title[i]}'
    summary of input : '{summary[i]}'
    output :
    """
    
    
    
    response = ollama.chat(
    model=ollama_model,
    messages=[
        {"role": "system", "content": "You are a classifier."},
        {'role': 'user', 'content': prompt}])
    
    # print(response['message']['content'])
    # response_ii_with_rule_2.append(response['message']['content'])

# %%
for i in range(len(title)):
    prompt = f"""Classify '0' or '1' without further explanation.

Read the following inputs and their corresponding summaries. For each input, determine whether it refers to a "Business Product" or a "Non-Business Product".

* A product can be classified as tangible (physical object) or intangible (cannot be perceived directly).
* A business product is a good or service offered for sale to customers.
* Classify the input as a "1" if it meets the above criteria, and "0" otherwise.

Read each input and its summary, and infer an output based on the provided criteria.
    
    input : '{title[i]}'
    summary of input : '{summary[i]}'
    output :
    """
    
    
    
    response = ollama.chat(
    model=ollama_model,
    messages=[
        {"role": "system", "content": "You are a classifier."},
        {'role': 'user', 'content': prompt}])
    
    # print(response['message']['content'])
    # response_ii_with_rule_3.append(response['message']['content'])

# %%
for i in range(len(title)):
    prompt = f"""Classify '0' or '1' without further explanation.

Read the summary of each input and determine whether it refers to a business product or not.

* A "Business Product" is a good or service offered for sale to customers, which can be tangible (physical object) or intangible (experienced indirectly).
* Classify the product as "1" if it meets this criteria, and "0" otherwise.

Please provide the summaries for each input, and I will determine the output based on the instruction and output criteria.
    
    input : '{title[i]}'
    summary of input : '{summary[i]}'
    output :
    """
    
    
    
    response = ollama.chat(
    model=ollama_model,
    messages=[
        {"role": "system", "content": "You are a classifier."},
        {'role': 'user', 'content': prompt}])
    
    # print(response['message']['content'])
    # response_ii_with_rule_4.append(response['message']['content'])

# %%
response_ii_with_rule_10time = []

# %%
# 10번 반복
for j in range(10):
    for i in range(len(title)):
        prompt = f"""Classify '0' or '1' without further explanation.

Read the summary of each input and determine whether it refers to a "Business Product" or a "Non-Business Product".

A "Business Product" refers to any good or service offered for sale to customers, which can be classified as tangible (physical object) or intangible (non-physical product).

Classify the input as a "1" if it meets this definition, and as a "0" otherwise.

Read each input summary and output either "1" or "0" based on the above definition.
    
    input : '{title[i]}'
    summary of input : '{summary[i]}'
    output :
    """
    
    
    
        response = ollama.chat(
        model=ollama_model,
        messages=[
            {"role": "system", "content": "You are a classifier."},
            {'role': 'user', 'content': prompt}])

        response_ii_with_rule_10time.append(response['message']['content'])

# %%
response_ii_with_rule_10time

# %%
r1 = response_ii_with_rule_10time[:100]
r2 =response_ii_with_rule_10time[100:200]
r3 =response_ii_with_rule_10time[200:300]
r4 =response_ii_with_rule_10time[300:400]
r5 =response_ii_with_rule_10time[400:500]
r6 =response_ii_with_rule_10time[500:600]
r7 =response_ii_with_rule_10time[600:700]
r8 =response_ii_with_rule_10time[700:800]
r9 =response_ii_with_rule_10time[800:900]
r10 = response_ii_with_rule_10time[900:1000]

# %%
a = [1,2,4,6,7,9,10,11,12,13,15,16,19,22,23,24,25,26,30,31,32,33,34,35,36,37,38,40,41,45,50,51,56,58,59,60,61,62,64,66,69,72,74,75,77,80,81,84,88,91,92,94,95,96,98,99]

# %%
# 설명 뽑기
response_ii_with_rule_explanation = []
for i in a:
    prompt = f"""Classify '0' or '1' with explanation.

Read the summary of each input and determine whether it refers to a "Business Product" or a "Non-Business Product".

A "Business Product" refers to any good or service offered for sale to customers, which can be classified as tangible (physical object) or intangible (non-physical product).

Classify the input as a "1" if it meets this definition, and as a "0" otherwise.

Read each input summary and output either "1" or "0" based on the above definition.
    
    input : '{title[i]}'
    summary of input : '{summary[i]}'
    output :
    """
    
    
    
    response = ollama.chat(
    model=ollama_model,
    messages=[
        {"role": "system", "content": "You are a classifier."},
        {'role': 'user', 'content': prompt}])
    
    print(response['message']['content'])
    response_ii_with_rule_explanation.append(response['message']['content'])

# %% [markdown]
# # 2차 생성

# %%
ii_prompt_with_rule_2 = []

# %%
for i in range(5):
    prompt = """I gave a business expert an instruction, inputs, and summary of the wiki article for each inputs.
    The expert read the instruction and summary, and inference an output for every one of the inputs.
    
    The information of output are as follows:
    In business, a **product** refers to a tangible or intangible item that satisfies a customer's needs or wants. It can be a physical good, a service, an experience, or even an idea.

Here are some key characteristics and definitions of a product in business:

**Definition:**

* A product is anything that can be offered to a market to satisfy a customer's needs or wants.
* It has a unique set of features, benefits, and attributes that distinguish it from other products.

**Criteria:**

1. **Tangibility:** Products can be tangible (physical goods) or intangible (services, experiences, ideas).
2. **Uniqueness:** Each product has distinct characteristics, features, or benefits that differentiate it from others.
3. **Customer Value:** A product provides value to the customer by satisfying their needs, wants, or desires.
4. **Marketability:** Products can be marketed and sold to customers through various channels.
5. **Competitive Differentiation:** Products are distinguishable from competitors' offerings.

**Types of Products:**

1. **Tangible Products:** Physical goods, such as food, clothing, electronics, cars, etc.
2. **Intangible Products:** Services, experiences, or ideas, such as consulting, education, healthcare, software, etc.
3. **Hybrid Products:** Combination of tangible and intangible elements, such as a restaurant meal (tangible food + intangible service).

**Examples:**

1. Apple iPhone (tangible product)
2. Amazon Web Services (intangible product - cloud computing service)
3. Starbucks Coffee Experience (hybrid product - tangible coffee + intangible atmosphere)

In summary, a product in business is anything that provides value to customers and can be marketed and sold through various channels. It has unique characteristics, features, or benefits that distinguish it from other products.

    The expert inference the product as a “1” if it was a business product and a “0” otherwise.

    Here are the input-output pairs:
    Input: *Ion trap
    Summary : **Summary of Ion trap
    Output: "1"

    Input: *Laser metal deposition
    Summary : **Summary of Laser metal
    Output: "1"

    Input: *Ion trap
    Summary : **Summary of Ion trap
    Output: "1"

    Input: *Air separation
    Summary : **Summary of Air separation
    Output: "1"

    Input: *Cathode-ray tube
    Summary : **Summary of Cathode-ray tube
    Output: "1"

    Input: *Joret line
    Summary : **Summary of Joret line
    Output: "0"

    Input: *John Rowsworm
    Summary : **Summary of John Rowsworm
    Output: "0"

    Input: *Salishan languages
    Summary : **Summary of Salishan languages
    Output: "0"

    Input: *Structral violence
    Summary : **Summary of Structral violence
    Output: "0"

    Input: *Night flying restrictions
    Summary : **Summary of Night flying restrictions
    Output: "0"

    The instruction was"""

    response = ollama.chat(
        model=ollama_model,
        messages=[
        {"role": "system", "content": "You are a expert of prompt engineering. Generate proper instruction."},
        {'role': 'user', 'content': prompt}],
        )

    # print(response['message']['content'])
    ii_prompt_with_rule_2.append(response['message']['content'])

# %% [markdown]
# # 2차 추론

# %%
response_ii_with_rule_6 = []
response_ii_with_rule_7 = []
response_ii_with_rule_8 = []
response_ii_with_rule_9 = []
response_ii_with_rule_10 = []

# %%
for i in range(len(title)):
    prompt = f"""Read the provided summary of each input and determine whether it describes a business product or not. 

A business product is defined as anything that can be offered to a market to satisfy a customer's needs or wants, having unique characteristics, features, or benefits that distinguish it from other products.

Criteria for a Business Product:
* Tangibility (physical goods or intangible services, experiences, or ideas)
* Uniqueness (distinct characteristics, features, or benefits)
* Customer Value (provides value to the customer by satisfying their needs, wants, or desires)
* Marketability (can be marketed and sold to customers through various channels)
* Competitive Differentiation (distinguishable from competitors' offerings)

For each input, read the corresponding summary and determine whether it describes a business product according to the above criteria. If it does, output "1". Otherwise, output "0".

Please follow this instruction to evaluate each input and provide an output of "1" or "0" accordingly.
    
    input : '{title[i]}'
    summary of input : '{summary[i]}'
    output :
    """
    
    
    
    response = ollama.chat(
    model=ollama_model,
    messages=[
        {"role": "system", "content": "You are a classifier."},
        {'role': 'user', 'content': prompt}])
    
    # print(response['message']['content'])
    response_ii_with_rule_6.append(response['message']['content'])

# %%
for i in range(len(title)):
    prompt = f"""Read the summary of each input and determine whether it refers to a business product or not. A business product is anything that can be offered to a market to satisfy a customer's needs or wants, having unique characteristics, features, or benefits that distinguish it from other products.

For each input, output "1" if you believe it is a business product, and "0" otherwise.

Refer to the provided definition and criteria of a product in business to make your judgment.
    
    input : '{title[i]}'
    summary of input : '{summary[i]}'
    output :
    """
    
    
    
    response = ollama.chat(
    model=ollama_model,
    messages=[
        {"role": "system", "content": "You are a classifier."},
        {'role': 'user', 'content': prompt}])
    
    # print(response['message']['content'])
    response_ii_with_rule_7.append(response['message']['content'])

# %%
for i in range(len(title)):
    prompt = f"""Read the summary of each input and determine whether it represents a product in a business context or not.

A product refers to a tangible or intangible item that satisfies a customer's needs or wants. It can be a physical good, a service, an experience, or even an idea.

Key Characteristics and Definitions:
* A product is anything that can be offered to a market to satisfy a customer's needs or wants.
* It has a unique set of features, benefits, and attributes that distinguish it from other products.
* Products can be tangible (physical goods) or intangible (services, experiences, ideas).
* Each product provides value to the customer by satisfying their needs, wants, or desires.
* Products can be marketed and sold to customers through various channels.
* Products are distinguishable from competitors' offerings.

For each input, read the corresponding summary and infer an output as follows:

* If the input represents a business product (i.e., it satisfies the definition and characteristics of a product), output "1".
* Otherwise, output "0".

Please follow this instruction to classify each input based on the provided summaries.
    
    input : '{title[i]}'
    summary of input : '{summary[i]}'
    output :
    """
    
    
    
    response = ollama.chat(
    model=ollama_model,
    messages=[
        {"role": "system", "content": "You are a classifier."},
        {'role': 'user', 'content': prompt}])
    
    # print(response['message']['content'])
    response_ii_with_rule_8.append(response['message']['content'])

# %%
for i in range(len(title)):
    prompt = f"""Read the summary of each input and determine whether it refers to a business product or not. Based on your understanding of what constitutes a business product, infer an output for each input.

A business product is defined as anything that can be offered to a market to satisfy a customer's needs or wants. It has unique characteristics, features, or benefits that distinguish it from other products.

Key Characteristics and Definitions:
* A product provides value to the customer by satisfying their needs, wants, or desires.
* Products can be tangible (physical goods) or intangible (services, experiences, ideas).
* Each product has distinct characteristics, features, or benefits that differentiate it from others.
* Products can be marketed and sold to customers through various channels.

* If the input refers to a business product, output "1".
* If the input does not refer to a business product, output "0".

Please read each summary carefully and provide an output for each input based on your understanding of what constitutes a business product.
    
    input : '{title[i]}'
    summary of input : '{summary[i]}'
    output :
    """
    
    
    
    response = ollama.chat(
    model=ollama_model,
    messages=[
        {"role": "system", "content": "You are a classifier."},
        {'role': 'user', 'content': prompt}])
    
    # print(response['message']['content'])
    response_ii_with_rule_9.append(response['message']['content'])

# %%
for i in range(len(title)):
    prompt = f"""Read the summary of each input and determine whether it describes a business product or not.

A business product refers to a tangible or intangible item that satisfies a customer's needs or wants. It can be a physical good, a service, an experience, or even an idea.

Characteristics of a Business Product:
* Tangibility: Can be tangible (physical goods) or intangible (services, experiences, ideas)
* Uniqueness: Has distinct characteristics, features, or benefits that differentiate it from others
* Customer Value: Provides value to the customer by satisfying their needs, wants, or desires
* Marketability: Can be marketed and sold to customers through various channels
* Competitive Differentiation: Is distinguishable from competitors' offerings

For each input, read its summary and infer an output as follows:
* If the summary describes a business product, output "1"
* If the summary does not describe a business product, output "0"

Please follow this instruction to evaluate each input and provide the corresponding output.
    
    input : '{title[i]}'
    summary of input : '{summary[i]}'
    output :
    """
    
    
    
    response = ollama.chat(
    model=ollama_model,
    messages=[
        {"role": "system", "content": "You are a classifier."},
        {'role': 'user', 'content': prompt}])
    
    # print(response['message']['content'])
    response_ii_with_rule_10.append(response['message']['content'])

# %%
response_ii_with_rule_6

# %%
response_ii_with_rule_7

# %%
response_ii_with_rule_8

# %%
response_ii_with_rule_9

# %%
response_ii_with_rule_10
